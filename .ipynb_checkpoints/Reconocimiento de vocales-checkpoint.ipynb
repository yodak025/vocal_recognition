# %% [markdown]
# # Grupo 7: Identificación de vocales con Naive Bayes
#
# - Con este trabajo analizaremos la voz de varios audios, con el fin de poder identificarlos con la mayor exactitud posible. El algoritmo de Naive Bayes con el de la librería de código que usaremos (Librosa) se encargará de analizar las señales dadas, de las cuales utilizaremos un 75% para entrenamiento y un 25% para test. Este algoritmo comparará los distintos datos obtenidos de los archivos y a partir de la señales, compararemos los distintos valores obtenidos.
#
# - Este trabajo se basara en el análisis de las vocales españolas y sus formantes. Un software informático se encargará de analizar las señales de los audios de las vocales (Xtrain) comparándolas con otras (Xtest).
#
# - Utilizaremos el algoritmo de Naive Bayes para comparar los distintos datos obtenidos a partir de las señales adquiridas, compararemos los diferentes coeficientes con los distintos valores en frecuencia de los ficheros de audio, para así poder diferenciar las características de cada vocal.
#
#
# - Primero, se introduce en el código un número de ejemplos cuya etiqueta (vocal) es conocida (proceso de entrenamiento) y se diseña un conjunto de reglas para hallar la función de clasificación, una vez obtenida esta función tendremos la posibilidad de verificar nuestra probabilidad de acierto con los archivos que usaremos en el proceso de test. Las entradas del clasificador serán las características extraídas (los coeficientes de mel y los coeficientes de LCP) de cada archivo de audio. La salida del clasificador será la etiqueta (vocal) al que pertenece cada audio.
#
#
# - Utilizaremos los dos tipos de coeficientes diferentes para comparar los resultados y ver cuál de los dos coeficientes se adecua mejor a cada audio.

# %% [markdown]
# # Metodología
#
# -	Tendremos una carpeta de audios que sera nuestra base de datos que contiene 32 audios en total, de los cuales serán 8 audios de cada vocal en los cuales dirán la vocal en entonaciones y tiempos distintos.
#
# -	Nuestro código tratara de identificar la vocal correspondiente a cada audio. Como  entrada tenemos una  señal de voz en este caso (a_p.wav) y a la salida obtenemos la vocal correspondiente, teniendo como posibles resultados: 'a', 'e', 'i', 'o' y 'u'.
#
# -	En el siguiente hito vamos a poner un ejemplo de un audio de cada vocal en tiempo  y frecuencia, para poder ver sus características de forma representativa.

# %% [markdown]
# ## Representación en el tiempo

# %%
# Importamos todas las librerias que necesitamos
import matplotlib.pyplot as plt
import scipy.io.wavfile as wf
#import sounddevice as sd
import numpy as np
import scipy.signal as sig
import scipy as sc
import tds_utils as tds
import sys
sys.path.append('../') #allows to import a module in a diff folder
from tds_utils import *


# Datos de ejemplo
vocal_a = 'vocals/a_p.wav'
vocal_e = 'vocals/e_p.wav'
vocal_i = 'vocals/i_p.wav'
vocal_o = 'vocals/o_p.wav'
vocal_u = 'vocals/u_p.wav'


# vocal_a será a, vocal_e será e, vocal_i será i, vocal_o será o y vocal_u será u.
fs_a,y_a = wf.read(vocal_a)
fs_e,y_e = wf.read(vocal_e)
fs_o,y_o = wf.read(vocal_i)
fs_i,y_i = wf.read(vocal_o)
fs_u, y_u = wf.read(vocal_u)

y_a = y_a/np.max(y_a)
y_e = y_e/np.max(y_e)
y_i = y_i/np.max(y_i)
y_o = y_o/np.max(y_o)
y_u = y_u/np.max(y_u)

plt.figure(figsize = (25,10))


# Vocal a
t_a = np.arange(0,len(y_a)/fs_a, 1/fs_a)
plt.subplot(5,1,1)
plt.title("Vocals in Time")
plt.plot(t_a, y_a)
plt.ylabel('Amplitude Vocal a')
plt.xlabel('Time[sec]')

# Vocal e
t_e = np.arange(0,len(y_e)/fs_e, 1/fs_e)
plt.subplot(5,1,2)
plt.plot(t_e, y_e)
plt.ylabel('Amplitude Vocal e')
plt.xlabel('Time[sec]')

# Vocal i
t_i = np.arange(0,len(y_i)/fs_i, 1/fs_i)
plt.subplot(5,1,3)
plt.plot(t_i, y_i)
plt.ylabel('Amplitude Vocal i')
plt.xlabel('Time[sec]')

# Vocal o
t_o = np.arange(0,len(y_o)/fs_o, 1/fs_o)
plt.subplot(5,1,4)
plt.plot(t_o, y_o)
plt.ylabel('Amplitude Vocal o')
plt.xlabel('Time[sec]')

# Vocal u

t_u = np.arange(0,len(y_u)/fs_u, 1/fs_u)
plt.subplot(5,1,5)
plt.plot(t_u, y_u)
plt.ylabel('Amplitude Vocal u')
plt.xlabel('Time[sec]')

print('\n Análisis en tiempo(seg) de todos los locutores\n')
# Out:
#  Análisis en tiempo(seg) de todos los locutores

# %% [markdown]
# ## Representación en frecuencia

# %%
# Importamos my spectra desde tds utils
from tds_utils import my_spectra

# Estimación de densidad espectral en potencia de cada vocal(FFT)
psd_a,f_a = my_spectra(y_a,fs_a)
psd_e,f_e = my_spectra(y_e,fs_e)
psd_i,f_i = my_spectra(y_i,fs_i)
psd_o,f_o = my_spectra(y_o,fs_o)
psd_u,f_u = my_spectra(y_u,fs_u)

# Representamos en frecuencias positivas

plt.figure(figsize =(25,10))
psd,f = my_spectra(y_a,fs_a)     # Establecemos una f
idx1 = (f_a>=0)
idx2 = (f_e>=0)
idx3 = (f_i>=0)
idx4 = (f_o>=0)
idx5 = (f_u>=0)

plt.subplot(5,1,1)
plt.title("Vocales en Frecuencia")
plt.plot(f_a[idx1],psd_a[idx1])
plt.ylabel('|FFT| del Vocal a')
plt.xlabel('Frecuencia[Hz]')

plt.subplot(5,1,2)
plt.plot(f_e[idx2],psd_e[idx2])
plt.ylabel('|FFT| de Vocal e')
plt.xlabel('Frecuencia[Hz]')

plt.subplot(5,1,3)
plt.plot(f_i[idx3],psd_i[idx3])
plt.ylabel('|FFT| de Vocal i')
plt.xlabel('Frecuencia[Hz]')

plt.subplot(5,1,4)
plt.plot(f_o[idx4],psd_o[idx4])
plt.ylabel('|FFT| de Vocal o')
plt.xlabel('Frecuencia[Hz]')


plt.subplot(5,1,5)
plt.plot(f_u[idx5],psd_u[idx5])
plt.ylabel('|FFT| de Vocal u')
plt.xlabel('Frecuencia[Hz]')

print('\r\n\r\n Análisis de Espectro en Frecuencia [Hz]')
# Out:
#  Análisis de Espectro en Frecuencia [Hz]

# %% [markdown]
# ## Audios de vocales (Base de datos)

# %% [markdown]
# - Lo primero que hacemos es ver todos los archivos de la carpeta y sacar las características de cada audio de forma independiente. Todos nuestros audios están guardados en la carpeta de vocales llamada "vocals".

# %%
import os, sys

directorio = os.listdir("vocals/")
Archivos = []

for file in directorio:
    Archivos.append(file)
    
print(Archivos)
# Out:
# ['I_flaco_nr.wav', 'a_p.wav', 'o_p.wav', 'A_Agu_nr.wav', 'I_Bruno_nr.wav', 'a_g.wav', 'o_g.wav', 'e_g.wav', 'u_g.wav', 'U_Bruno_nr.wav', 'O_Agu_nr.wav', 'E_Bruno_nr.wav', 'U_Bruno_Hablada_nr.wav', 'E_Bruno_Hablada_nr.wav', 'I_Bruno_Hablada_nr.wav', 'O_flaco_nr.wav', 'I_Agu_nr.wav', 'U_Mari_nr.wav', 'A_Bruno_Hablada_nr.wav', 'i_g.wav', 'O_Agu_Hablada_nr.wav', 'U_Agu_nr.wav', 'O_Mari_nr.wav', 'E_Agu_nr.wav', 'U_flaco_nr.wav', 'cepstral_2.m', 'u_p.wav', 'I_Agu_Hablada_nr.wav', 'O_Bruno_Hablada_nr.wav', 'e_p.wav', 'vocal_noise.wav', 'I_Mari_nr.wav', 'O_Bruno_nr.wav', 'A_Bruno_nr.wav', 'E_Mari_nr.wav', 'A_flaco_nr.wav', 'U_Agu_Hablada_nr.wav', 'i_p.wav', 'Vocals.py', 'E_flaco_nr.wav', 'E_Agu_Hablada_nr.wav']

# %% [markdown]
# Cálculo de las características de cada audio

# %%
from NaiveVocals import *

model = NaiveVocals('A_Mari_nr.wav')
model._fit_mel()
model._fit_lpc()

print(model.train)# Aqui tendríamos que poner los coeficientes de cada audio
# Out:
# {'I_flaco_nr.wav': {'MEL': [-390.0084635416667, 158.810400390625, -77.76156412760416, 71.00845540364584, 71.05362955729167, -55.356038411458336, -1.6154244740804036, 27.01912638346354, -26.578751627604166, -11.445712280273437, -12.369510904947917, -25.600628662109376, 7.623518880208334, -7.114891560872396, -32.845045979817705], 'LPC': [-0.4102525690929022, 0.03245946031605781, -1.414487999246854, 0.09450069409222289, -0.11052396638421033, 1.2996999228268973, 0.07938631939839093, 0.28335206044261546, -0.7797096990654152, 0.17372094737911958, -0.2635846028161603, 0.17473981707771916], 'result': 'i'}, 'a_p.wav': {'MEL': [-226.76518811677633, 239.83634868421052, -65.83232036389802, -27.824167351973685, -11.958579615542764, -27.968814247532894, 34.260832134046055, 7.721649973016036, -26.009465267783717, 13.2573386744449, 6.74093949167352, 1.8269229688142474, 9.023298564710116, -25.641991866262334, -12.71669568513569], 'LPC': [-1.7336810616931524, 0.9074918831388934, 0.5668432067662221, -0.6551953552389136, 0.06203720702657132, -0.24808994584813632, 0.462180758724477, 0.22796534122632808, -0.8605575867795434, 0.5349968412500883, -0.07849826867619915, -0.024173188207223553], 'result': 'a'}, 'o_p.wav': {'MEL': [-296.73109654017856, 204.4438011532738, 14.479094005766369, 9.473149617513021, -22.153889973958332, -47.61715552920387, 11.864849272228422, 9.339859008789062, -18.208868117559526, 9.969332740420388, 2.924556550525484, -15.801686604817709, 4.319481259300595, 3.667482648577009, -0.1151730219523112], 'LPC': [-1.8312977514563913, 0.5870889555349897, 0.4077020604579438, 0.7724147890351878, -1.1835750323331558, 0.06793321768629619, -0.11816117161017736, 0.9417469729942236, -0.6719430094997154, 0.07613039221384045, -0.01050624397972069, 0.03396418765222876], 'result': 'o'}, 'A_Agu_nr.wav': {'MEL': [-362.22474500868054, 110.32205539279514, -145.88712565104166, -39.925801595052086, -8.563551161024305, -39.04448784722222, 30.320058186848957, 2.2743937174479165, -43.916412353515625, 7.393736945258246, -0.9699738820393881, -30.75200737847222, -3.597529093424479, -1.5968070560031467, -4.463772243923611], 'LPC': [-0.9381101430414892, 0.8205948122594923, 0.09018285647378795, 0.43259712059333966, -0.2877194123241924, 0.3727519356441462, 0.3025680636436728, -0.19161405907839008, 0.1473947420959718, 0.08607559144021724, -0.10412335369618726, 0.15609816056298126], 'result': 'a'}, 'I_Bruno_nr.wav': {'MEL': [-456.60973307291664, 126.99131673177084, -84.34166666666667, 63.66820475260417, 68.38334147135417, -50.836767578125, 0.580014991760254, 27.64140625, -24.854534912109376, -14.8191650390625, -13.246053059895834, -24.193115234375, -5.8692372639973955, -22.67476806640625, -29.023551432291665], 'LPC': [-0.560133618530897, 0.14543915728117424, -1.5979469842523866, 0.38250987190236574, -0.1451280782865184, 1.4936295304777703, -0.30752523230799605, 0.4448220995001888, -0.9407504458140127, 0.31140281741217735, -0.3365883718204422, 0.22025148929837252], 'result': 'i'}, 'a_g.wav': {'MEL': [-337.9630650111607, 186.52572195870536, -73.84316580636161, -17.466193062918528, -4.85743168422154, -36.11860874720982, 18.732478550502233, 3.5254388536725725, -21.512680053710938, 19.717320033482142, 9.842071533203125, -11.955633980887276, -7.469725472586496, -22.705889020647323, -9.150210789271764], 'LPC': [-1.1497965336992657, 0.29007434688826694, 0.547892058266994, -0.31462537861791573, -0.07988035306074148, -0.1836470525338315, 0.4550669804548666, -0.05779398773116824, -0.4860886494279327, 0.3862322531661089, -0.13451509780565024, 0.04848133391658464], 'result': 'a'}, 'o_g.wav': {'MEL': [-345.34735107421875, 189.17391967773438, 2.2220945358276367, 23.005481719970703, -19.17898178100586, -63.78164291381836, 12.531237602233887, 19.56220054626465, -20.83358383178711, 6.314726829528809, 0.3548092842102051, -26.443103790283203, -2.713296413421631, 6.141321182250977, 2.5372180938720703], 'LPC': [-1.149551634369115, -0.4070362813370253, 0.8011950389881225, 1.0326014853634 ...

# %% [markdown]
# ### Características de cada audio y salidas reales confirmadas (soluciones correctas).

# %%
# Aquí deberíamos de poner la lista de los coeficientes con el resultado

from NaiveVocals import *

model = NaiveVocals('A_Mari_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('a_p.wav')
model.fit()
model.predict()

model = NaiveVocals('o_p.wav')
model.fit()
model.predict()

model = NaiveVocals('A_Agu_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('I_Bruno_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('a_g.wav')
model.fit()
model.predict()

model = NaiveVocals('o_g.wav')
model.fit()
model.predict()

model = NaiveVocals('e_g.wav')
model.fit()
model.predict()

model = NaiveVocals('u_g.wav')
model.fit()
model.predict()

model = NaiveVocals('U_Bruno_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('E_Bruno_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('U_Bruno_Hablada_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('E_Bruno_Hablada_nr.wav')
model.fit()
model.predict()


model = NaiveVocals('I_Bruno_Hablada_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('O_flaco_nr.wav')
model.fit()
model.predict()

model = NaiveVocals('I_Agu_nr.wav')
model.fit()
model.predict()
# Out:
# Tu archivo es A_Mari_nr.wav
# Predicción coeficientes de MEL: ['a']
# Predicción coeficientes LPC: ['a']
# Tu archivo es a_p.wav
# Predicción coeficientes de MEL: ['a']
# Predicción coeficientes LPC: ['a']
# Tu archivo es o_p.wav
# Predicción coeficientes de MEL: ['o']
# Predicción coeficientes LPC: ['o']
# Tu archivo es A_Agu_nr.wav
# Predicción coeficientes de MEL: ['a']
# Predicción coeficientes LPC: ['a']
# Tu archivo es I_Bruno_nr.wav
# Predicción coeficientes de MEL: ['i']
# Predicción coeficientes LPC: ['i']
# Tu archivo es a_g.wav
# Predicción coeficientes de MEL: ['a']
# Predicción coeficientes LPC: ['a']
# Tu archivo es o_g.wav
# Predicción coeficientes de MEL: ['o']
# Predicción coeficientes LPC: ['o']
# Tu archivo es e_g.wav
# Predicción coeficientes de MEL: ['e']
# Predicción coeficientes LPC: ['e']
# Tu archivo es u_g.wav
# Predicción coeficientes de MEL: ['u']
# Predicción coeficientes LPC: ['u']
# Tu archivo es U_Bruno_nr.wav
# Predicción coeficientes de MEL: ['u']
# Predicción coeficientes LPC: ['u']
# Tu archivo es E_Bruno_nr.wav
# Predicción coeficientes de MEL: ['e']
# Predicción coeficientes LPC: ['e']
# Tu archivo es U_Bruno_Hablada_nr.wav
# Predicción coeficientes de MEL: ['u']
# Predicción coeficientes LPC: ['u']
# Tu archivo es E_Bruno_Hablada_nr.wav
# Predicción coeficientes de MEL: ['e']
# Predicción coeficientes LPC: ['e']
# Tu archivo es I_Bruno_Hablada_nr.wav
# Predicción coeficientes de MEL: ['i']
# Predicción coeficientes LPC: ['i']
# Tu archivo es O_flaco_nr.wav
# Predicción coeficientes de MEL: ['o']
# Predicción coeficientes LPC: ['o']
# Tu archivo es I_Agu_nr.wav
# Predicción coeficientes de MEL: ['i']
# Predicción coeficientes LPC: ['i']

# %% [markdown]
# ## Resultado Final
#
# - Primero vamos con la función accuracy a calcular con el porcentaje de precisión que tiene el programa con cada uno de los dos métodos, utlizando los coeficientes LCP o los coecifientes Mel y averiguando con cuál de los dos hay más precisión en cada audio.
#
# - Por último haremos la prueba con tres audios de diferentes vocales, obteniendo la respuesta que da el programa.

# %% [markdown]
# Ejemplo de uso de la función accuracy:

# %%
from NaiveVocals import *

model = NaiveVocals('A_Mari_nr.wav')

model.accuracy()
# Out:
# Tamaño de entrenamiento: 27
# Tamaño de prueba: 11
# Total: 38
# MEL: ['u', 'e', 'i', 'o', 'a', 'e', 'a', 'u', 'i', 'e', 'i']
# LPC: ['u', 'e', 'i', 'u', 'a', 'e', 'u', 'o', 'e', 'e', 'i']
# Resultados: ['o', 'e', 'i', 'o', 'a', 'e', 'a', 'u', 'i', 'e', 'e']
# Precisión MEL: 0.8181818181818182
# Precisión LPC: 0.45454545454545453

# %%
from tds_utils import *
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
import scipy.io.wavfile as wf


filename = 'A_Mari_nr.wav'
fs,y = wf.read(filename)
print(f'El primer audio será: {filename}')
Audio(y,rate = fs)
# Out:
# El primer audio será: A_Mari_nr.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from NaiveVocals import *

model = NaiveVocals('A_Mari_nr.wav')
model.fit()
model.predict()
# Out:
# Tu archivo es A_Mari_nr.wav
# Predicción coeficientes de MEL: ['a']
# Predicción coeficientes LPC: ['a']

# %%
from tds_utils import *
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
import scipy.io.wavfile as wf

filename = 'vocals/I_Bruno_nr.wav'
fs,y = wf.read(filename)
print(f'El segundo audio será: {filename}')
Audio(y,rate = fs)
# Out:
# El segundo audio será: vocals/I_Bruno_nr.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from NaiveVocals import *

model = NaiveVocals('vocals/I_Bruno_nr.wav')
model.fit()
model.predict()
# Out:
# Tu archivo es vocals/I_Bruno_nr.wav
# Predicción coeficientes de MEL: ['i']
# Predicción coeficientes LPC: ['i']

# %%
from tds_utils import *
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
import scipy.io.wavfile as wf

filename = 'vocals/O_Agu_nr.wav'
fs,y = wf.read(filename)
print(f'El tercer audio será: {filename}')
Audio(y,rate = fs)
# Out:
# El tercer audio será: vocals/O_Agu_nr.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from NaiveVocals import *

model= NaiveVocals('O_Agu_nr.wav')
model.fit()
model.predict()
# Out:
# Tu archivo es O_Agu_nr.wav
# Predicción coeficientes de MEL: ['o']
# Predicción coeficientes LPC: ['o']
